# %%
import pandas as pd
import numpy as np
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\HP\AppData\Local\Temp\ipykernel_16008\854837523.py:4: SyntaxWarning: invalid escape sequence '\s'
#   raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)

# %%
data.shape
# Out:
# (506, 13)

# %%
dataset=pd.DataFrame(data,columns=['CIRM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','TAET'])

# %%
target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
dataset['PRICE']=target
dataset.isnull().sum()
# Out:
# CIRM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# TAET       0
# PRICE      0
# dtype: int64

# %%
dataset.describe()
# Out:
#              CIRM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# preparing the dataset

# %%
dataset.head(2)
# Out:
#       CIRM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
#
#    PTRATIO      B  TAET  PRICE
# 0     15.3  396.9  4.98   24.0
# 1     17.8  396.9  9.14   21.6

# %%
dataset.corr()
# Out:
#              CIRM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CIRM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14788\3447316344.py in <module>
# ----> 1 import seaborn as sns
#       2 sns.pairplot(dataset)
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# plt.scatter(dataset['CIRM'],dataset['PRICE'])
# plt.xlabel('CIRM')
# plt.ylabel('PRICE')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14788\3459741776.py in <module>
# ----> 1 plt.scatter(dataset['CIRM'],dataset['PRICE'])
#       2 plt.xlabel('CIRM')
#       3 plt.ylabel('PRICE')
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# plt.scatter(dataset['INDUS'],dataset['PRICE'])
# plt.xlabel('indus')
# plt.ylabel('price')
# plt.show()

# %%
# plt.scatter(dataset['CHAS'],dataset['PRICE'])
# plt.xlabel('chas')
# plt.ylabel('price')
# plt.show()

# %%
# deviding the features in into train and test split
# you need to seperate the  x and  y
x=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]

# %%
# Train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train.head(1)
# Out:
#       CIRM   ZN  INDUS  CHAS    NOX    RM   AGE     DIS  RAD    TAX  PTRATIO  \
# 5  0.02985  0.0   2.18   0.0  0.458  6.43  58.7  6.0622  3.0  222.0     18.7
#
#         B  TAET
# 5  394.12  5.21

# %%
# standerdized the data
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train_stand=scaler.fit_transform(x_train)
x_test_stand=scaler.transform(x_test)

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))

# %% [raw]
# Model training

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([-1.33470103e-01,  3.58089136e-02,  4.95226452e-02,  3.11983512e+00,
#        -1.54170609e+01,  4.05719923e+00, -1.08208352e-02, -1.38599824e+00,
#         2.42727340e-01, -8.70223437e-03, -9.10685208e-01,  1.17941159e-02,
#        -5.47113313e-01])

# %%
lr.intercept_
# Out:
# 31.631084035694286

# %%
# on which parameters the model has been train
lr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
# pridiction with the test data
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([28.64896005, 36.49501384, 15.4111932 , 25.40321303, 18.85527988,
#        23.14668944, 17.3921241 , 14.07859899, 23.03692679, 20.59943345,
#        24.82286159, 18.53057049, -6.86543527, 21.80172334, 19.22571177,
#        26.19191985, 20.27733882,  5.61596432, 40.44887974, 17.57695918,
#        27.44319095, 30.1715964 , 10.94055823, 24.02083139, 18.07693812,
#        15.934748  , 23.12614028, 14.56052142, 22.33482544, 19.3257627 ,
#        22.16564973, 25.19476081, 25.31372473, 18.51345025, 16.6223286 ,
#        17.50268505, 30.94992991, 20.19201752, 23.90440431, 24.86975466,
#        13.93767876, 31.82504715, 42.56978796, 17.62323805, 27.01963242,
#        17.19006621, 13.80594006, 26.10356557, 20.31516118, 30.08649576,
#        21.3124053 , 34.15739602, 15.60444981, 26.11247588, 39.31613646,
#        22.99282065, 18.95764781, 33.05555669, 24.85114223, 12.91729352,
#        22.68101452, 30.80336295, 31.63522027, 16.29833689, 21.07379993,
# ...

# %%
# lets plot a scatter plot for the prediction
plt.scatter(y_test,y_pred)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # lets plot a scatter plot for the prediction
# ----> 2 plt.scatter(y_test,y_pred)
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# now we will check the score or errors
residuals=y_test-y_pred

# %%
residuals
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 residuals
#
# NameError: name 'residuals' is not defined

# %%
# plotting this residual
# so error is mostly normally distibuted
sns.kdeplot(residuals)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 # plotting this residual
#       2 # so error is mostly normally distibuted
# ----> 3 sns.kdeplot(residuals)
#       4 plt.show()
#
# NameError: name 'sns' is not defined

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 21.517444231177205
# 3.1627098714574053

# %% [markdown]
# # r2 square error and adjusted r square

# %%
from sklearn.metrics import r2_score
score=r2_score(y_pred,y_test)

# %%
# so it will give you the score
score
# Out:
# 0.6693702691495593

# %%
dataset.describe()
